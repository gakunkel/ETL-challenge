# %% [markdown]
# # CURRENCIES AND BTC HISTORICAL DATA

# %%
# %matplotlib notebook

# %%
# Import dependencies

import os
import csv
import pandas as pd
import json
import requests
import string
import numpy as py
from datetime import timezone
import sqlite3

# %%
# Establish URL connection to coingecko

# url1 = "https://api.coingecko.com/api/v3/"

# https://api.coingecko.com/api/v3/simple/price?ids=btc&vs_currencies=eth

# %%
# Supported currencies

user_currency = str(input("What currency would you like to compare against?"))
supported_currencies = requests.get(f"{url1}simple/supported_vs_currencies").json()

if user_currency in supported_currencies:
    print(f"Data for {user_currency} is available.")
else:
    print(f"Data for {user_currency} is not available.")

# %%
# BTC current exchange rates 

user_vs_btc = str(input("What currency would you like to compare against Bitcoin (BTC)?"))
btc_exchange_rates = requests.get(f"{url1}exchange_rates").json()
btc_exchange_rates['rates'][user_vs_btc]

# %%
# BTC historical exchange rate (from n days back, n =1-30 or "max"); against a currency (a symbol, e.g. "usd"))
# Also... Market Caps, and Total Volumes

user_currency = str(input("What currency would you like to compare against Bitcoin (BTC)?"))
n_days = str(input("Include hourly updates from how many days back (1-30 or 'max')?"))

historical_exchange = requests.get(f"{url1}coins/bitcoin/market_chart?vs_currency={user_currency}&days={n_days}").json()

# print(historical_exchange)

len(historical_exchange['prices'])

# %%
generic_30_day = "https://api.coingecko.com/api/v3/coins/{coin}/market_chart?vs_currency={currency}&days=30&interval=daily"

coins = ["bitcoin", "ethereum", "dogecoin"]
currencies = ["usd", "eur", "hkd"]

# Storing data for past 30 days. Most recent (03/19/2021 is at the end)
# Price lists
btc_usd = []
btc_eur = []
btc_hkd = []

eth_usd = []
eth_eur = []
eth_hkd = []

doge_usd = []
doge_eur = []
doge_hkd = []

# Volume lists (USD only)
btc_vol = []
eth_vol = []
doge_vol = []

# Iterating through each coin and each currency to get 30 days of price and volume
for coin in coins:
    usd_response = requests.get(f"https://api.coingecko.com/api/v3/coins/{coin}/market_chart?vs_currency=usd&days=30&interval=daily").json()
    usd_prices = usd_response['prices']
    usd_volumes = usd_response['total_volumes']
    
    for price in usd_prices:
        if coin == 'bitcoin':
            btc_usd.append(price[1])
        elif coin == 'ethereum':
            eth_usd.append(price[1])
        elif coin == 'dogecoin':
            doge_usd.append(price[1])
            
    for volume in usd_volumes:
        if coin == 'bitcoin':
            btc_vol.append(volume[1])
        elif coin == 'ethereum':
            eth_vol.append(volume[1])
        elif coin == 'dogecoin':
            doge_vol.append(volume[1])
    
    
    eur_response = requests.get(f"https://api.coingecko.com/api/v3/coins/{coin}/market_chart?vs_currency=eur&days=30&interval=daily").json()
    eur_prices = eur_response['prices']
    
    for price in eur_prices:
        if coin == 'bitcoin':
            btc_eur.append(price[1])
        elif coin == 'ethereum':
            eth_eur.append(price[1])
        elif coin == 'dogecoin':
            doge_eur.append(price[1])
            
    hkd_response = requests.get(f"https://api.coingecko.com/api/v3/coins/{coin}/market_chart?vs_currency=hkd&days=30&interval=daily").json()
    hkd_prices = hkd_response['prices']
    
    for price in hkd_prices:
        if coin == 'bitcoin':
            btc_hkd.append(price[1])
        elif coin == 'ethereum':
            eth_hkd.append(price[1])
        elif coin == 'dogecoin':
            doge_hkd.append(price[1])

# %%
print(len(btc_usd))
# Out:
# 31

# %%
# Dates for today, back 30 days

end_date = '2021-03-19'
start_date = '2021-02-17'

dates = []

from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2021, 2, 18)
end_date = date(2021, 3, 20)
for single_date in daterange(start_date, end_date):
    dates.append(single_date.strftime("%Y-%m-%d"))
    
dates = sorted(dates, reverse=True)
print(dates)
print(len(dates))
# Out:
# ['2021-03-19', '2021-03-18', '2021-03-17', '2021-03-16', '2021-03-15', '2021-03-14', '2021-03-13', '2021-03-12', '2021-03-11', '2021-03-10', '2021-03-09', '2021-03-08', '2021-03-07', '2021-03-06', '2021-03-05', '2021-03-04', '2021-03-03', '2021-03-02', '2021-03-01', '2021-02-28', '2021-02-27', '2021-02-26', '2021-02-25', '2021-02-24', '2021-02-23', '2021-02-22', '2021-02-21', '2021-02-20', '2021-02-19', '2021-02-18']
# 30

# %%
# Making data dictionaries to insert into pandas dataframes

days_ago = list(range(30))

btc_data = {
    'Coin': 'Bitcoin',
    'Symbol': 'BTC',
    'Date': dates,
    'days_ago': days_ago,
    'total_vol_usd': sorted(btc_vol[1::], reverse=True),
    'USD': sorted(btc_usd[1::], reverse=True),
    'EUR': sorted(btc_eur[1::], reverse=True),
    'HKD': sorted(btc_hkd[1::], reverse=True)
}

eth_data = {
    'Coin': 'Ethereum',
    'Symbol': 'ETH',
    'Date': dates,
    'days_ago': days_ago,
    'total_vol_usd': sorted(eth_vol[1::], reverse=True),
    'USD': sorted(eth_usd[1::], reverse=True),
    'EUR': sorted(eth_eur[1::], reverse=True),
    'HKD': sorted(eth_hkd[1::], reverse=True),
}

doge_data = {
    'Coin': 'Dogecoin',
    'Symbol': 'DOGE',
    'Date': dates,
    'days_ago': days_ago,
    'total_vol_usd': sorted(doge_vol[1::], reverse=True),
    'USD': sorted(doge_usd[1::], reverse=True),
    'EUR': sorted(doge_eur[1::], reverse=True),
    'HKD': sorted(doge_hkd[1::], reverse=True)
}

btc_df = pd.DataFrame(btc_data)
eth_df = pd.DataFrame(eth_data)
doge_df = pd.DataFrame(doge_data)

btc_df.to_csv('btc_df.csv')
eth_df.to_csv('eth_df.csv')
doge_df.to_csv('doge_df.csv')

btc_df
# Out:
#        Coin Symbol        Date  days_ago  total_vol_usd           USD  \
# 0   Bitcoin    BTC  2021-03-19         0   1.166896e+11  61315.197933
# 1   Bitcoin    BTC  2021-03-18         1   1.015320e+11  59428.967566
# 2   Bitcoin    BTC  2021-03-17         2   7.735179e+10  59014.925632
# 3   Bitcoin    BTC  2021-03-16         3   7.435720e+10  58833.729116
# 4   Bitcoin    BTC  2021-03-15         4   7.314059e+10  58243.270609
# 5   Bitcoin    BTC  2021-03-14         5   7.139724e+10  57922.409593
# 6   Bitcoin    BTC  2021-03-13         6   7.059449e+10  57788.868103
# 7   Bitcoin    BTC  2021-03-12         7   6.733276e+10  57669.303527
# 8   Bitcoin    BTC  2021-03-11         8   6.460523e+10  57353.861472
# 9   Bitcoin    BTC  2021-03-10         9   6.356055e+10  56830.253335
# 10  Bitcoin    BTC  2021-03-09        10   6.336827e+10  56377.633478
# 11  Bitcoin    BTC  2021-03-08        11   6.321990e+10  56038.727759
# 12  Bitcoin    BTC  2021-03-07        12   6.321857e+10  56020.487720
# 13  Bitcoin    BTC  2021-03-06        13   6.122327e+10  55805.329249
# 14  Bitcoin    BTC  2021-03-05        14   6.074959e+10  54700.273439
# 15  Bitcoin    BTC  2021-03-04        15   6.035538e+10  54410.856295
# 16  Bitcoin    BTC  2021-03-03        16   5.998497e+10  52328.535913
# 17  Bitcoin    BTC  2021-03-02        17   5.967959e+10  51313.092620
# 18  Bitcoin    BTC  2021-03-01        18   5.921227e+10  50577.457469
# 19  Bitcoin    BTC  2021-02-28        19   5.838701e+10  49849.378714
# 20  Bitcoin    BTC  2021-02-27        20   5.741825e+10  49787.339959
# 21  Bitcoin    BTC  2021-02-26        21   5.656811e+10  49091.814882
# 22  Bitcoin    BTC  2021-02-25        22   5.356895e+10  49019.368592
# 23  Bitcoin    BTC  2021-02-24        23   5.349954e+10  48727.451201
# 24  Bitcoin    BTC  2021-02-23        24   5.205992e+10  48691.894832
# 25  Bitcoin    BTC  2021-02-22        25   5.194839e+10  48532.236790
# 26  Bitcoin    BTC  2021-02-21        26   5.098976e+10  46992.665450
# 27  Bitcoin    BTC  2021-02-20        27   4.810408e+10  46653.526399
# 28  Bitcoin    BTC  2021-02-19        28   4.614632e+10  46551.487477
# 29  Bitcoin    BTC  2021-02-18        29   4.147879e+10  44970.163460
#
#              EUR            HKD
# 0   51295.129602  475956.158193
# 1   49729.090338  461340.538029
# 2   49344.565835  458264.470966
# 3   49256.512604  455868.598999
# 4   48753.403312  452325.976039
# 5   48605.879622  449767.510487
# 6   48228.104398  448356.088957
# 7   47981.150784  447117.607254
# 8   47746.846624  445206.481983
# 9   47559.182587  441301.124710
# 10  46979.341207  437101.148229
# 11  46797.456223  434805.312276
# 12  46522.935901  434473.579994
# 13  46244.615154  433314.430288
# 14  45969.836297  424586.257449
# 15  44724.635657  421888.176994
# 16  44151.783548  406553.477639
# 17  43033.776439  398402.034937
# 18  41970.034025  392292.517199
# 19  41322.446632  386569.469579
# 20  41197.900141  386148.119359
# 21  41137.103142  381117.186526
# 22  40960.337200  380554.760258
# 23  40721.482241  378099.926681
# 24  40159.697960  377550.135660
# 25  40067.294268  376489.069558
# 26  38648.271831  364385.357240
# 27  38645.728514  361868.077517
# 28  38561.297063  361076.612613
# 29  37203.276588  348821.416015

# %%
# Connect to SQL
conn = sqlite3.connect('Crypto.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE Bitcoin (Coin, Symbol, Date, Days Ago, Total Vol USD, USD, EUR, HKD)')
conn.commit()

btc_df.to_sql('Bitcoin', conn, if_exists='replace', index = False)
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# Historical Price for BTC

user_coin = str(input("What is the name of the coin you would like to see price data for?"))
date = str(input("For which date (DD-MM-YYYY format)?"))

historical_price = requests.get(f"{url1}coins/{user_coin}/history?date={date}").json()

historical_price

# %% [markdown]
# # NEWS ARTICLES BY KEYWORD

# %%
from config import news_key
from nltk.tokenize import word_tokenize
from datetime import timedelta, date

# %%
# Search through the NewsAPI for articles with a specific keyword in the title

query_keyword = str(input("What keyword would you like to query?"))
query_from = str(input("From which date (YYYY-MM-DD format)?"))

query_url = f"https://newsapi.org/v2/everything?q={query_keyword}&from={'2021-03-19'}&sortBy=popularity&apiKey={news_key}"

response = requests.get(query_url).json()

print(response)
print(len(response['articles']))

# https://newsapi.org/v2/everything?q={Apple}&from=2021-03-16&sortBy=popularity&apiKey=API_KEY
# Out:
# What keyword would you like to query?bitcoin
# From which date (YYYY-MM-DD format)?2021-03-19
# {'status': 'ok', 'totalResults': 408, 'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Reuters Staff', 'title': 'U.S. CFTC orders Coinbase to pay $6.5 million for false reporting, other actions - Reuters', 'description': 'The U.S. Commodity Futures Trading Commission on Friday ordered digital asset exchange operator Coinbase Inc to pay $6.5 million to settle charges of reckless false, misleading, or inaccurate reporting as well as wash trading by a former employee on Coinbase’…', 'url': 'https://www.reuters.com/article/us-coinbase-cftc-idUSKBN2BB2J3', 'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210319&t=2&i=1555538571&r=LYNXMPEH2I1GO&w=800', 'publishedAt': '2021-03-19T22:08:00Z', 'content': 'By Reuters Staff\r\nFILE PHOTO: Representation of the virtual currency Bitcoin is seen on a motherboard in this picture illustration taken April 24, 2020. REUTERS/Dado Ruvic/Illustration\r\nWASHINGTON (R… [+516 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Kitiphong Thaichareon', 'title': 'Thai central bank plans stablescoins regulations this year - Reuters', 'description': 'Thai central bank plans stablescoins regulations this year\xa0\xa0Reuters', 'url': 'https://www.reuters.com/article/thailand-economy-crypto-currency-idUSL4N2LH11F', 'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800', 'publishedAt': '2021-03-19T07:46:00Z', 'content': '* Will regulate only asset-backed stablecoins, not Bitcoin\r\n* Services using baht-backed stablecoins need cenbank approval\r\n* Cenbank developing retail c.bank digital currency\r\nBANGKOK, March 19 (Reu… [+1671 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Sinéad Carew', 'title': 'UPDATE 1-NFT-related stocks gyrate wildly as digital asset buzz grows - Reuters', 'description': 'The popularity of non-fungible tokens (NFT), a type of digital asset that is authenticated by blockchain, is spreading to equities as investors turn their focus to shares of online art trading platforms and companies making NFT-related announcements, sparking…', 'url': 'https://www.reuters.com/article/usa-stocks-nft-idUSL1N2LG2H9', 'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800', 'publishedAt': '2021-03-19T00:20:00Z', 'content': '(Updates share prices)\r\nMarch 18 (Reuters) - The popularity of non-fungible tokens (NFT), a type of digital asset that is authenticated by blockchain, is spreading to equities as investors turn their… [+2977 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Kevin Buckland, Sagarika Jaisinghani', 'title': 'FOREX-Dollar defensive as Treasury yields slip from near 14-month highs - Reuters', 'description': "The U.S. dollar gave up early gains on Friday as Treasury yields dipped from near 14-month highs, while investors digested the Federal Reserve's pushback against expectations of any early interest-rate hikes.", 'url': 'https://www.reuters.com/article/uk-global-forex-idUSKBN2BB03F', 'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210319&t=2&i=1555423971&r=LYNXMPEH2I01V&w=800', 'publishedAt': '2021-03-19T08:23:00Z', 'content': 'TOKYO (Reuters) - The U.S. dollar gave up early gains on Friday as Treasury yields dipped from near 14-month highs, while investors digested the Federal Reserves pushback against expectations of any … [+2373 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Kevin Buckland', 'title': "Dollar strengthens amid higher U.S. yields on Fed's lower-for-longer mantra - Reuters", 'description': "The safe-haven U.S. dollar strengthened again on Friday, supported by higher Treasury yields and falling stock markets, as investors continued to digest the Federal Reserve's pushback against expectations of any early interest-rate hikes.", 'url': 'https://www.reuters.com/article/us-global-forex-idUSKBN2BB04D', 'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210319&t ...
# 20

# %%
# # Lists for descriptions
# btc_descriptions = []
# eth_descriptions = []
# doge_descriptions = []

# # Today's date
# today = dates[0]

# # Iterate through coins, dates, and article descriptions
# for coin in coins:   
#     query_keyword = coin
    
#     for date in dates:
        
#         query_url = f"https://newsapi.org/v2/everything?q={query_keyword}&from={date}&to={today}&sortBy=popularity&apiKey={news_key}"
#         response = requests.get(query_url).json()
        
#         df = 
        
#             descriptions = list(item[3])

#             descriptions_list = list(descriptions)

#             for description in descriptions:

#                 if (coin == 'bitcoin') and (description not in btc_descriptions):
#                             btc_descriptions.append(description)

#                 elif (coin == 'ethereum') and (description not in eth_descriptions):
#                             eth_descriptions.append(description)

#                 elif (coin == 'dogecoin') and (description not in doge_descriptions):
#                             doge_descriptions.append(description)
                
# print(btc_descriptions)

# %%
for date in dates:
    query_url = f"https://newsapi.org/v2/everything?q=bitcoin&from={date}&to={today}&sortBy=popularity&apiKey={news_key}"
    response = requests.get(query_url).json()
# Out:
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
query_url = f"https://newsapi.org/v2/everything?q=bitcoin&from=2021-03-10&to={today}&sortBy=popularity&apiKey={news_key}"
response = requests.get(query_url).json()
print(response)

articles_test_df = pd.DataFrame(response['articles'])
articles_test_df.head(5)
# Out:
# {'status': 'ok', 'totalResults': 4488, 'articles': [{'source': {'id': None, 'name': 'Lifehacker.com'}, 'author': 'Mike Winters on Two Cents, shared by Mike Winters to Lifehacker', 'title': 'Why NFT Collectibles Are Overhyped', 'description': 'NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hype—and should we be reassured by celebrity endorsements from Logan Paul, Paris Hilton, Lindsay Lohan, Rob Gronk…', 'url': 'https://twocents.lifehacker.com/why-nft-collectibles-are-overhyped-1846452668', 'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/dclkyg7wdn18rjbbxbsw.png', 'publishedAt': '2021-03-11T01:35:00Z', 'content': 'NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hypeand should we be reassured by celebrity endorseme… [+4477 chars]'}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'https://www.engadget.com/about/editors/saqib-shah', 'title': 'US charges CEO of company selling encrypted devices to drug traffickers', 'description': "The US Department of Justice has charged two individuals associated with encrypted phone software maker Sky Global, including the company's CEO, for allegedly facilitating global drug trafficking organizations.", 'url': 'https://www.engadget.com/us-charges-ceo-selling-encrypted-devices-drug-traffickers-121552423.html', 'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/i.KFSBEWW2bgEDxplCyoOA--~B/aD0xNzAxO3c9MjY0NDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-03/55195440-8585-11eb-b57f-1de02853bf2a.cf.jpg', 'publishedAt': '2021-03-15T12:15:52Z', 'content': 'The US Department of Justice (DoJ) has announced an indictment against the head and associate of a Canada-based company that allegedly supplied custom encrypted phones to international drug trafficke… [+2142 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Adi Robertson', 'title': 'India will reportedly introduce bill to make owning cryptocurrency illegal', 'description': 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.', 'url': 'https://www.theverge.com/2021/3/15/22332677/india-cryptocurrency-trading-mining-possession-ban-law-report', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8QbQcH2MDU6sAUA=/0x243:2040x1311/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10432811/mdoying_180308_2373_0091still.jpg', 'publishedAt': '2021-03-15T22:25:02Z', 'content': 'One of the strictest crackdowns worldwide\r\nPhoto by Michele Doying / The Verge\r\nIndia is reportedly moving forward with a sweeping ban on cryptocurrencies. According to Reuters, the countrys legislat… [+1656 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Justine Calma', 'title': 'The climate controversy swirling around NFTs', 'description': 'Most NFTs are bought and sold with Ethereum, a cryptocurrency that guzzles up energy and pumps out a lot of greenhouse gas emissions. Artists are fighting over whether there can be a more sustainable future for crypto art.', 'url': 'https://www.theverge.com/2021/3/15/22328203/nft-cryptoart-ethereum-blockchain-climate-change', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/pYrvxU6TUFVYkAwb6h1U4BPYMj0=/0x431:6000x3572/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22366636/1230723200.jpg', 'publishedAt': '2021-03-15T13:51:11Z', 'content': 'Famed auction house Christies just sold its first purely digital piece of art for a whopping $69 million. For that price, the buyer got a digital file of a collage of 5,000 images and a complex legac… [+12891 chars]'}, {'source': {'id': 'techcru ...
#                                        source  \
# 0      {'id': None, 'name': 'Lifehacker.com'}
# 1      {'id': 'engadget', 'name': 'Engadget'}
# 2    {'id': 'the-verge', 'name': 'The Verge'}
# 3    {'id': 'the-verge', 'name': 'The Verge'}
# 4  {'id': 'techcrunch', 'name': 'TechCrunch'}
#
#                                               author  \
# 0  Mike Winters on Two Cents, shared by Mike Wint...
# 1  https://www.engadget.com/about/editors/saqib-shah
# 2                                      Adi Robertson
# 3                                      Justine Calma
# 4                                     Rebecca Bellan
#
#                                                title  \
# 0                 Why NFT Collectibles Are Overhyped
# 1  US charges CEO of company selling encrypted de...
# 2  India will reportedly introduce bill to make o...
# 3       The climate controversy swirling around NFTs
# 4    His Majesty Elon the First, Technoking of Tesla
#
#                                          description  \
# 0  NFTs have become an investing phenomenon, with...
# 1  The US Department of Justice has charged two i...
# 2  India’s legislature is reportedly considering ...
# 3  Most NFTs are bought and sold with Ethereum, a...
# 4  Last week, Elon Musk made $25 billion in one d...
#
#                                                  url  \
# 0  https://twocents.lifehacker.com/why-nft-collec...
# 1  https://www.engadget.com/us-charges-ceo-sellin...
# 2  https://www.theverge.com/2021/3/15/22332677/in...
# 3  https://www.theverge.com/2021/3/15/22328203/nf...
# 4  http://techcrunch.com/2021/03/15/his-majesty-e...
#
#                                           urlToImage           publishedAt  \
# 0  https://i.kinja-img.com/gawker-media/image/upl...  2021-03-11T01:35:00Z
# 1  https://s.yimg.com/uu/api/res/1.2/i.KFSBEWW2bg...  2021-03-15T12:15:52Z
# 2  https://cdn.vox-cdn.com/thumbor/IdgNJaOIQBsN8Q...  2021-03-15T22:25:02Z
# 3  https://cdn.vox-cdn.com/thumbor/pYrvxU6TUFVYkA...  2021-03-15T13:51:11Z
# 4  https://techcrunch.com/wp-content/uploads/2021...  2021-03-15T14:34:13Z
#
#                                              content
# 0  NFTs have become an investing phenomenon, with...
# 1  The US Department of Justice (DoJ) has announc...
# 2  One of the strictest crackdowns worldwide\r\nP...
# 3  Famed auction house Christies just sold its fi...
# 4  Last week, Elon Musk made $25 billion in one d...

# %%
print(list(articles_test_df['description']))
# Out:
# ['NFTs have become an investing phenomenon, with everything from GIFs to sports highlights selling for millions of dollars. But how much of this is hype—and should we be reassured by celebrity endorsements from Logan Paul, Paris Hilton, Lindsay Lohan, Rob Gronk…', "The US Department of Justice has charged two individuals associated with encrypted phone software maker Sky Global, including the company's CEO, for allegedly facilitating global drug trafficking organizations.", 'India’s legislature is reportedly considering a near-total ban on private cryptocurrencies like Bitcoin or Ethereum, including owning the virtual currency. The government has discussed plans for a national digital currency as an alternative.', 'Most NFTs are bought and sold with Ethereum, a cryptocurrency that guzzles up energy and pumps out a lot of greenhouse gas emissions. Artists are fighting over whether there can be a more sustainable future for crypto art.', 'Last week, Elon Musk made $25 billion in one day. On Monday, he crowned himself “Technoking of Tesla.” In Musk-speak, this new title still translates into the Chief Executive Officer of the electric car company.\xa0 The eccentric billionaire is nothing if not cr…', 'OpenSea has been one of a handful of NFT marketplaces to explode in popularity in recent weeks as collectors wade into the trading of non-fungible tokens on the blockchain. While new startups have been popping up everyday, platforms that launched in crypto’s …', 'One of the bigger startups in Europe operating a trading platform for cryptocurrency has closed a big round of funding on the heels of very rapid growth and plans to open its platform to a wider stream of assets. Bitpanda, a “neobroker” that wants to make it …', 'Spending millions for a digital work of art that could be screenshotted feels similar to traipsing around a strip of concrete as a tourist activity. The optics don’t make immediate sense — there’s hardly any appeal in something as accessible as a Google image…', 'A proposed law in India would make it a crime to mine, trade, or even hold cryptocurrencies like bitcoin in the country, according to a new report from Reuters citing a senior government official. It’s estimated roughly 8 million people in India hold some for…', 'The hacker behind last year’s big Twitter hack\r\n has just been sentenced to hard time.\nGraham Ivan Clark, the teenage hacker who broke\r\n into Twitter’s systems, took over verified accounts, and used them to scam users out of Bitcoin, was sentenced to three ye…', "Mashable's new series Don't @ Me takes unpopular opinions and backs them up with...reasons. We all have our ways, but we may just convince you to change yours. And if not, chill.\n\nCryptocurrency is a mess. The amount of energy required to generate and keep re…", 'Most people have been able to pass on assets like a family home without federal tax, but that could be changing.', 'Tesla CFO Zach Kirkhorn is now "Master of Coin," Tesla says in SEC filing.', "Nvidia hobbled the RTX 3060's mining abilities to reserve the card for gamers.", "Florida teen pleads guilty to attack that took over Twitter's internal systems.", "Bitcoin, the world's biggest cryptocurrency, on Saturday reached a record high, trading up to $59,755.", "Bitcoin, the world's biggest cryptocurrency, on Saturday crossed a record high of $60,000.", 'Morgan Stanley has become the first big U.S. bank to offer its wealth management clients access to Bitcoin funds, CNBC reported on Wednesday.', 'The Oakland Athletics are selling access to suites in the 2021 regular season for $64,800.', 'A new feature has appeared at smoke shops in Montana, gas stations in the Carolinas and delis in far-flung corners of New York City: a brightly-lit bitcoin ATM, where customers can buy or sell digital currency, and sometimes extract hard cash.']

# %%
# DataFrame of articles from query_date with headline containing query_keyword
articles_df = pd.DataFrame(response['articles'])
articles_df.head(5)
# Out:
#                                  source                                author  \
# 0  {'id': 'reuters', 'name': 'Reuters'}                         Reuters Staff
# 1  {'id': 'reuters', 'name': 'Reuters'}                 Kitiphong Thaichareon
# 2  {'id': 'reuters', 'name': 'Reuters'}                          Sinéad Carew
# 3  {'id': 'reuters', 'name': 'Reuters'}  Kevin Buckland, Sagarika Jaisinghani
# 4  {'id': 'reuters', 'name': 'Reuters'}                        Kevin Buckland
#
#                                                title  \
# 0  U.S. CFTC orders Coinbase to pay $6.5 million ...
# 1  Thai central bank plans stablescoins regulatio...
# 2  UPDATE 1-NFT-related stocks gyrate wildly as d...
# 3  FOREX-Dollar defensive as Treasury yields slip...
# 4  Dollar strengthens amid higher U.S. yields on ...
#
#                                          description  \
# 0  The U.S. Commodity Futures Trading Commission ...
# 1  Thai central bank plans stablescoins regulatio...
# 2  The popularity of non-fungible tokens (NFT), a...
# 3  The U.S. dollar gave up early gains on Friday ...
# 4  The safe-haven U.S. dollar strengthened again ...
#
#                                                  url  \
# 0  https://www.reuters.com/article/us-coinbase-cf...
# 1  https://www.reuters.com/article/thailand-econo...
# 2  https://www.reuters.com/article/usa-stocks-nft...
# 3  https://www.reuters.com/article/uk-global-fore...
# 4  https://www.reuters.com/article/us-global-fore...
#
#                                           urlToImage           publishedAt  \
# 0  https://static.reuters.com/resources/r/?m=02&d...  2021-03-19T22:08:00Z
# 1  https://s1.reutersmedia.net/resources_v2/image...  2021-03-19T07:46:00Z
# 2  https://s1.reutersmedia.net/resources_v2/image...  2021-03-19T00:20:00Z
# 3  https://static.reuters.com/resources/r/?m=02&d...  2021-03-19T08:23:00Z
# 4  https://static.reuters.com/resources/r/?m=02&d...  2021-03-19T01:52:00Z
#
#                                              content
# 0  By Reuters Staff\r\nFILE PHOTO: Representation...
# 1  * Will regulate only asset-backed stablecoins,...
# 2  (Updates share prices)\r\nMarch 18 (Reuters) -...
# 3  TOKYO (Reuters) - The U.S. dollar gave up earl...
# 4  TOKYO (Reuters) - The safe-haven U.S. dollar s...

# %%
headlines = articles_df['content']
headlines_list = list(headlines)

headlines_list[0]
# Out:
# 'By Reuters Staff\r\nFILE PHOTO: Representation of the virtual currency Bitcoin is seen on a motherboard in this picture illustration taken April 24, 2020. REUTERS/Dado Ruvic/Illustration\r\nWASHINGTON (R… [+516 chars]'

# %%
end_date = '2021-03-19'
start_date = '2021-02-17'

dates = []

from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2021, 2, 18)
end_date = date(2021, 3, 20)
for single_date in daterange(start_date, end_date):
    dates.append(single_date.strftime("%Y-%m-%d"))
    
dates = sorted(dates, reverse=True)
print(dates)
print(len(dates))
# Out:
# ['2021-03-19', '2021-03-18', '2021-03-17', '2021-03-16', '2021-03-15', '2021-03-14', '2021-03-13', '2021-03-12', '2021-03-11', '2021-03-10', '2021-03-09', '2021-03-08', '2021-03-07', '2021-03-06', '2021-03-05', '2021-03-04', '2021-03-03', '2021-03-02', '2021-03-01', '2021-02-28', '2021-02-27', '2021-02-26', '2021-02-25', '2021-02-24', '2021-02-23', '2021-02-22', '2021-02-21', '2021-02-20', '2021-02-19', '2021-02-18']
# 30

# %%
from datetime import datetime
my_date = datetime.now()
print(my_date.strftime('%Y-%m-%d'))
# Out:
# 2021-03-19

# %% [markdown]
# # SENTIMENT ANALYSIS w/ NLTK

# %%
import nltk
from pprint import pprint
import re

# mystr = 'This is a string, with words!'
# wordList = re.sub("[^\w]", " ",  mystr).split()

# %%
nltk.download([
...     "names",
...     "stopwords",
...     "state_union",
...     "twitter_samples",
...     "movie_reviews",
...     "averaged_perceptron_tagger",
...     "vader_lexicon",
...     "punkt",
... ])

# %%
words = [w for w in nltk.corpus.state_union.words() if w.isalpha()]

stopwords = nltk.corpus.stopwords.words("english")

words = [w for w in words if w.lower() not in stopwords]

words

def unique(list1):
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x.lower())
    return unique_list

unique_words = unique(words)

print(len(unique_words))
print(len(words))
# print(unique_words)

# %%
mystr = 'This is a string, with words!'
wordList = re.sub("[^\w]", " ",  mystr).split()

wordList
# pprint(nltk.word_tokenize(text), width=79, compact=True)
